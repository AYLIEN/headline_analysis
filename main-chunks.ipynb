# %% [markdown]
# # News Headline Analysis
#
# In this project we're analyzing news headlines produced by two journalists:
#
# - A finance reporter from the Business Insider who covers market updates (Akin Oyedele)
# - A celebrity reporter from the Huffington Post (Carly Ledbetter)
#
# Our objective is to find similarity and differences between the ways through which these reporters structure their headlines.

# %%
from pattern.en import parsetree

# %%
s = parsetree('The cat sat on the mat.')
for sentence in s:
    for chunk in sentence.chunks:
        print chunk.type, [(w.string, w.type) for w in chunk.words]
# Out:
# NP [(u'The', u'DT'), (u'cat', u'NN')]
# VP [(u'sat', u'VBD')]
# PP [(u'on', u'IN')]
# NP [(u'the', u'DT'), (u'mat', u'NN')]

# %% [markdown]
# ![The cat sat on the mat](https://raw.githubusercontent.com/AYLIEN/headline_analysis/master/parsetree.png)

# %%
import cPickle as pickle
author1 = pickle.load( open( "author1.p", "rb" ) )
author1[0]
# Out:
# {u'title': u"One corner of the real-estate market might've peaked"}

# %%
for story in author1:
    story["title_length"] = len(story["title"])
    story["title_chunks"] = [chunk.type for chunk in parsetree(story["title"])[0].chunks]
    story["title_chunks_length"] = len(story["title_chunks"])

# %%
author1[0]
# Out:
# {u'title': u"One corner of the real-estate market might've peaked",
#  'title_chunks': [u'NP', u'PP', u'NP', u'VP'],
#  'title_chunks_length': 4,
#  'title_length': 52}

# %%
import pandas as pd

df1 = pd.DataFrame.from_dict(author1)

# %%
df1.describe()
# Out:
#        title_chunks_length  title_length
# count           700.000000    700.000000
# mean              5.691429     57.730000
# std               3.762884     28.035283
# min               1.000000      9.000000
# 25%               2.000000     35.000000
# 50%               5.000000     53.000000
# 75%               7.000000     77.000000
# max              30.000000    188.000000

# %%
import difflib
v1 = author1[3]["title_chunks"]
v2 = author1[1]["title_chunks"]
sm=difflib.SequenceMatcher(None,v1,v2)
print v1, v2, sm.ratio()
# Out:
# [u'NP', u'NP', u'VP', u'NP', u'NP', u'VP', u'PP'] [u'NP', u'VP', u'NP', u'PP', u'NP', u'NP'] 0.615384615385

# %%
import numpy as np
chunks = [author["title_chunks"] for author in author1]
m = np.zeros((700,700))
for i, chunkx in enumerate(chunks):
    for j, chunky in enumerate(chunks):
        sm=difflib.SequenceMatcher(None,chunkx,chunky)
        m[i][j] = sm.ratio()

# %%
from sklearn.manifold import TSNE
tsne_model = TSNE(n_components=2, verbose=1, random_state=0)

# %%
tsne = tsne_model.fit_transform(m)
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 700 / 700
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] Error after 83 iterations with early exaggeration: 13.379313
# [t-SNE] Error after 144 iterations: 0.633875

# %%
from sklearn.cluster import MiniBatchKMeans

kmeans_model = MiniBatchKMeans(n_clusters=5, init='k-means++', n_init=1, 
                         init_size=1000, batch_size=1000, verbose=False, max_iter=1000)
kmeans = kmeans_model.fit(m)
kmeans_clusters = kmeans.predict(m)
kmeans_distances = kmeans.transform(m)

# %%
import bokeh.plotting as bp
from bokeh.models import HoverTool, BoxSelectTool
from bokeh.plotting import figure, show, output_notebook

colormap = np.array([
    "#1f77b4", "#aec7e8", "#ff7f0e", "#ffbb78", "#2ca02c", 
    "#98df8a", "#d62728", "#ff9896", "#9467bd", "#c5b0d5", 
    "#8c564b", "#c49c94", "#e377c2", "#f7b6d2", "#7f7f7f", 
    "#c7c7c7", "#bcbd22", "#dbdb8d", "#17becf", "#9edae5"
])

output_notebook()
plot_author1 = bp.figure(plot_width=900, plot_height=700, title="Author1",
    tools="pan,wheel_zoom,box_zoom,reset,hover,previewsave",
    x_axis_type=None, y_axis_type=None, min_border=1)

plot_author1.scatter(x=tsne[:,0], y=tsne[:,1],
                    color=colormap[kmeans_clusters],
                    source=bp.ColumnDataSource({
                        "chunks": [x["title_chunks"] for x in author1], 
                        "title": [x["title"] for x in author1],
                        "cluster": kmeans_clusters
                    }))

hover = plot_author1.select(dict(type=HoverTool))
hover.tooltips={"chunks": "@chunks (title: \"@title\")", "cluster": "@cluster"}
show(plot_author1)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ae50836f-3340-4768-b237-c4253ab13532">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="376f2cdb-96e7-4620-9d01-1625a819a814"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("376f2cdb-96e7-4620-9d01-1625a819a814");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '376f2cdb-96e7-4620-9d01-1625a819a814' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"dc3ff9c5-e82e-4b1b-94b1-0c7cab37c9fa":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"e9f9e17e-a94d-40c5-8def-02e87e8e7f78","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"a5a48a22-5f8a-4f0a-8e4b-03a8151b00ee","subtype":"Figure","type":"Plot"}},"id":"b93f2cc5-8f2f-4642-b9ee-d724aa7a460b","type":"PreviewSaveTool"},{"attributes":{"data_source":{"id":"8bb91057-23b2-414b-b6cd-a5470098e592","type":"ColumnDataSource"},"glyph":{"id":"db277fd7-cde9-4b55-8279-b54072f22f0c","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"8d6e4b6a-77af-48bc-9de3-f33c656dea61","type":"Circle"},"selection_glyph":null},"id":"020c1a71-e85c-4b40-aa7e-d9cebe22ed58","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"a5a48a22-5f8a-4f0a-8e4b-03a8151b00ee","subtype":"Figure","type":"Plot"}},"id":"f4140a47-9553-443d-9fd4-28cf37a884ee","type":"WheelZoomTool"},{"attributes":{"callback":null,"plot":{"id":"a5a48a22-5f8a-4f0a-8e4b-03a8151b00ee","subtype":"Figure","type":"Plot"},"tooltips":[["chunks","@chunks (title: \"@title\")"],["cluster","@cluster"]]},"id":"b377b301-7279-4785-9c12-512ebd879cb5","type":"HoverTool"},{"attributes":{"min_border":1,"plot_height":700,"plot_width":900,"renderers":[{"id":"e9f9e17e-a94d-40c5-8def-02e87e8e7f78","type":"BoxAnnotation"},{"id":"020c1a71-e85c-4b40-aa7e-d9cebe22ed58","type":"GlyphRenderer"}],"title":"Author1","tool_events":{"id":"e5a86fd9-1782-4976-90f7-de358cf6d9d8","type":"ToolEvents"},"tools":[{"id":"a8196511-49d9-45ab-8e2c-ec4905034670","type":"PanTool"},{"id":"f4140a47-9553-443d-9fd4-28cf37a884ee","type":"WheelZoomTool"},{"id":"66848789-95a2-4bfd-a674-feb153bd44a9","type":"BoxZoomTool"},{"id":"4ebc01ba-7ea6-46c9-bfbb-8c2974ce2ff5","type":"ResetTool"},{"id":"b377b301-7279-4785-9c12-512ebd879cb5","type":"HoverTool"},{"id":"b93f2cc5-8f2f-4642-b9ee-d724aa7a460b","type":"PreviewSaveTool"}],"x_range":{"id":"3a5bcc91-ce4c-4971-b286-704039152556","type":"DataRange1d"},"y_range":{"id":"6c5f01bc-cad3-4e6c-b0ed-1659c928b7ee","type":"DataRange1d"}},"id":"a5a48a22-5f8a-4f0a-8e4b-03a8151b00ee","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"e5a86fd9-1782-4976-90f7-de358cf6d9d8","type":"ToolEvents"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8d6e4b6a-77af-48bc-9de3-f33c656dea61","type":"Circle"},{"attributes":{"callback":null,"column_names":["chunks","cluster","title","y","x","line_color","fill_color"],"data":{"chunks":[["NP","PP","NP","VP"],["NP","VP","NP","PP","NP","NP"],["NP","VP","NP","PP","NP","VP","ADJP","PP","NP","VP","NP"],["NP","NP","VP","NP","NP","VP","PP"],["NP","VP","ADVP","NP","NP","NP","NP","NP","NP","NP","NP","NP","NP","NP","NP","NP","NP"],["VP","NP"],["NP","VP","PP","NP"],["NP","VP","PP","NP"],["NP","VP","ADVP"],["VP","NP"],["NP","VP","ADJP","PP","NP","NP","NP"],["NP","VP","ADJP","PP","NP"],["NP","VP","ADJP","PP","NP"],["NP","VP","NP","PP","NP","VP","ADJP","PP","NP","VP","NP"],["NP","VP","PP","NP","PP","NP"],["NP","VP","PP","NP","VP","PP","NP"],["NP","NP","VP"],["NP","NP","VP"],["VP","NP","VP","NP","NP","VP","ADVP"],["NP","PP","NP"],["NP","VP","PP","VP","PP","NP"],["VP","NP"],["ADVP","NP","VP","ADVP","PP","ADJP"],["NP","NP","VP"],["VP","NP","NP","VP","PP","ADVP","NP","NP","NP","NP","NP","NP","NP","NP"],["NP","VP","ADJP","PP","NP","NP","VP"],["NP","VP","NP","NP","VP"],["NP","PP","NP"],["NP","PP","NP"],["NP","PP","NP","VP"],["NP","NP","VP","NP"],["VP","NP"],["NP","VP","NP","VP"],["VP","NP","NP","VP","PP","ADVP","NP","NP","NP","NP","NP","NP","NP","NP","NP","NP"],["NP","VP","NP","PP","NP"],["VP","NP","VP","PP","NP","NP","NP"],["NP","VP"],["V ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[13]</strong>&gt;</code></p>

# %%
author2 = pickle.load( open( "author2.p", "rb" ) )
for story in author2:
    story["title_length"] = len(story["title"])
    story["title_chunks"] = [chunk.type for chunk in parsetree(story["title"])[0].chunks]
    story["title_chunks_length"] = len(story["title_chunks"])

# %%
pd.DataFrame.from_dict(author2).describe()
# Out:
#        title_chunks_length  title_length
# count           700.000000    700.000000
# mean              5.452857     62.532857
# std               1.896252      9.996154
# min               1.000000     35.000000
# 25%               4.000000     57.000000
# 50%               5.000000     62.000000
# 75%               7.000000     68.000000
# max              13.000000     96.000000

# %%
chunks_joint = [author["title_chunks"] for author in (author1+author2)]
print len(chunks_joint)
m_joint = np.zeros((1400,1400))
for i, chunkx in enumerate(chunks):
    for j, chunky in enumerate(chunks):
        sm=difflib.SequenceMatcher(None,chunkx,chunky)
        m_joint[i][j] = sm.ratio()
# Out:
# 1400

# %%
set1= [author["title_chunks"] for author in author1]
set2= [author["title_chunks"] for author in author2]
list_new = [itm for itm in set1 if itm in set2]
len(list_new)
# Out:
# 347

# %%
tsne_joint = tsne_model.fit_transform(m_joint)
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1400
# [t-SNE] Computed conditional probabilities for sample 1400 / 1400
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] Error after 83 iterations with early exaggeration: 12.344255
# [t-SNE] Error after 139 iterations: 0.789386

# %%
plot_joint = bp.figure(plot_width=900, plot_height=700, title="Author1 vs. Author2",
    tools="pan,wheel_zoom,box_zoom,reset,hover,previewsave",
    x_axis_type=None, y_axis_type=None, min_border=1)

plot_joint.scatter(x=tsne_joint[:,0], y=tsne_joint[:,1],
                    color=colormap[([0] * 700 + [1] * 700)],
                    source=bp.ColumnDataSource({
                        "chunks": [x["title_chunks"] for x in author1] + [x["title_chunks"] for x in author2], 
                        "title": [x["title"] for x in author1] + [x["title"] for x in author2]
                    }))

hover = plot_joint.select(dict(type=HoverTool))
hover.tooltips={"chunks": "@chunks (title: \"@title\")"}
show(plot_joint)
# Out:
#     <div class="plotdiv" id="10aa3759-ca5b-4989-97a5-83d6457f8d8e"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("10aa3759-ca5b-4989-97a5-83d6457f8d8e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '10aa3759-ca5b-4989-97a5-83d6457f8d8e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"2fcff535-4f28-497e-ada0-76d04ace4c09":{"roots":{"references":[{"attributes":{"callback":null},"id":"a364e7a7-227b-4dd8-9232-645b57d2447a","type":"DataRange1d"},{"attributes":{"data_source":{"id":"eb32ed1f-fc90-493d-8ad8-8e15ef51e3be","type":"ColumnDataSource"},"glyph":{"id":"7dfe86e0-2b0d-4629-9bba-9fdb0d15011b","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"1c080fa3-f2df-4881-b9ea-4f0c8f72e570","type":"Circle"},"selection_glyph":null},"id":"4d875d4a-e202-46f3-88ae-06dd42e8f49e","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["chunks","cluster","title","y","x","line_color","fill_color"],"data":{"chunks":[["NP","PP","NP","VP"],["NP","VP","NP","PP","NP","NP"],["NP","VP","NP","PP","NP","VP","ADJP","PP","NP","VP","NP"],["NP","NP","VP","NP","NP","VP","PP"],["NP","VP","ADVP","NP","NP","NP","NP","NP","NP","NP","NP","NP","NP","NP","NP","NP","NP"],["VP","NP"],["NP","VP","PP","NP"],["NP","VP","PP","NP"],["NP","VP","ADVP"],["VP","NP"],["NP","VP","ADJP","PP","NP","NP","NP"],["NP","VP","ADJP","PP","NP"],["NP","VP","ADJP","PP","NP"],["NP","VP","NP","PP","NP","VP","ADJP","PP","NP","VP","NP"],["NP","VP","PP","NP","PP","NP"],["NP","VP","PP","NP","VP","PP","NP"],["NP","NP","VP"],["NP","NP","VP"],["VP","NP","VP","NP","NP","VP","ADVP"],["NP","PP","NP"],["NP","VP","PP","VP","PP","NP"],["VP","NP"],["ADVP","NP","VP","ADVP","PP","ADJP"],["NP","NP","VP"],["VP","NP","NP","VP","PP","ADVP","NP","NP","NP","NP","NP","NP","NP","NP"],["NP","VP","ADJP","PP","NP","NP","VP"],["NP","VP","NP","NP","VP"],["NP","PP","NP"],["NP","PP","NP"],["NP","PP","NP","VP"],["NP","NP","VP","NP"],["VP","NP"],["NP","VP","NP","VP"],["VP","NP","NP","VP","PP","ADVP","NP","NP","NP","NP","NP","NP","NP","NP","NP","NP"],["NP","VP","NP","PP","NP"],["VP","NP","VP","PP","NP","NP","NP"],["NP","VP"],["VP","NP","NP","VP","PP","ADVP"],["NP","VP","PP","NP","VP"],["NP","VP","NP","PP","NP","NP"],["NP","VP","NP","PP","NP","NP"],["NP","VP","NP"],["NP","VP","NP"],["NP","VP","ADVP","NP","NP","NP","NP","NP","NP","NP","NP","NP"],["NP","NP","VP","NP","NP","VP","PP"],["VP","NP","NP","VP","PP","ADVP","NP","NP","NP","NP","NP","NP","NP"],["NP","PP","NP","NP","PP","NP","VP"],["NP","PP","NP","NP","PP","NP","VP"],["NP","VP"],["NP","NP","VP","NP","VP","NP","PP","NP"],["NP","PP","NP","VP","PP","NP","PP","NP"],["NP","NP","VP","NP","ADJP"],["NP","NP","VP","PP","VP","NP"],["NP","VP","PP","NP"],["VP","NP"],["VP","NP"],["NP","VP","ADJP","PP","VP"],["VP","NP"],["VP","NP"],["VP","NP"],["VP","NP","NP","VP","PP","ADVP","NP","NP","NP","NP","NP","NP","NP"],["NP","VP","PP","VP","NP","VP"],["NP","VP","NP","NP","VP","ADVP","PP"],["NP","VP","ADVP"],["NP","VP","ADJP","PP","VP","PP","NP"],["VP","NP"],["NP","PP","NP","VP","PP","NP","PP","NP"],["VP","NP","NP","VP","PP","ADVP"],["NP","VP","PP","NP","NP","VP"],["NP","VP","PP","NP"],["NP","VP","NP","VP"],["VP","NP"],["NP","VP"],["NP","VP","NP","ADJP","PP","NP"],["NP"],["VP","NP","NP","VP","PP","ADVP","NP","NP","NP","NP","NP","NP","NP","NP","NP"],["NP","VP","PP","NP","PP","NP","VP","NP"],["NP","VP","PP","NP","PP","NP","VP","NP"],["NP","VP","NP","PP","NP"],["NP","VP","NP","PP","NP"],["VP","NP","NP","VP","PP","ADVP","NP","NP","NP","NP","NP","NP","NP","NP","NP","NP","NP","NP","NP","ADJP","NP"],["NP","VP","NP"],["NP","VP","NP"],["NP","VP","NP"],["VP","NP"],["VP","NP","NP","VP","ADJP","NP","PP"],["NP","VP","NP","PP","VP","NP"],["NP","NP","VP","NP","VP","NP","PP","NP"],["NP","VP"],["NP","NP","VP","NP","ADJP"],["VP","NP","NP","VP","PP","ADVP","NP","NP","NP","ADJP","NP","NP","NP","NP"],["NP","VP","NP","NP","PP","NP","NP"],["NP","VP","NP","NP","PP","NP","NP"],["NP","ADVP","NP","VP","PP","NP"],["ADJP","PP","NP","PP","NP"],["NP","NP","PP","NP","VP","NP","PP","NP","NP"],["NP","VP","NP","VP"],["VP","NP"],["NP","VP","PP","NP","VP","PP","NP"],["NP","VP","PP","NP","VP","PP","NP"],["PP","NP","VP","PP","ADVP"],["PP","NP","VP","PP","ADVP"],["PP","NP","VP","PP","ADVP"],["NP","VP"],["NP","VP"],["NP","VP","NP","PP","NP","VP","ADVP"],["VP" ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[19]</strong>&gt;</code></p>

# %%
from pattern.en import parsetree

# %%
s = parsetree('The cat sat on the mat.')
for sentence in s:
    for chunk in sentence.chunks:
        print chunk.type, [(w.string, w.type) for w in chunk.words]
# Out:
# NP [(u'The', u'DT'), (u'cat', u'NN')]
# VP [(u'sat', u'VBD')]
# PP [(u'on', u'IN')]
# NP [(u'the', u'DT'), (u'mat', u'NN')]

# %%
import cPickle as pickle
author1 = pickle.load( open( "author1.p", "rb" ) )
author1[0]
# Out:
# {u'title': u"One corner of the real-estate market might've peaked"}

# %%
for story in author1:
    story["title_length"] = len(story["title"])
    story["title_chunks"] = [chunk.type for chunk in parsetree(story["title"])[0].chunks]
    story["title_chunks_length"] = len(story["title_chunks"])

# %%
author1[0]
# Out:
# {u'title': u"One corner of the real-estate market might've peaked",
#  'title_chunks': [u'NP', u'PP', u'NP', u'VP'],
#  'title_chunks_length': 4,
#  'title_length': 52}

# %%
import pandas as pd

df1 = pd.DataFrame.from_dict(author1)

# %%
df1.describe()
# Out:
#        title_chunks_length  title_length
# count           700.000000    700.000000
# mean              5.691429     57.730000
# std               3.762884     28.035283
# min               1.000000      9.000000
# 25%               2.000000     35.000000
# 50%               5.000000     53.000000
# 75%               7.000000     77.000000
# max              30.000000    188.000000

# %%
import difflib
v1 = author1[3]["title_chunks"]
v2 = author1[1]["title_chunks"]
sm=difflib.SequenceMatcher(None,v1,v2)
print v1, v2, sm.ratio()
# Out:
# [u'NP', u'NP', u'VP', u'NP', u'NP', u'VP', u'PP'] [u'NP', u'VP', u'NP', u'PP', u'NP', u'NP'] 0.615384615385

# %%
chunks = [author["title_chunks"] for author in author1]
m = np.zeros((700,700))
for i, chunkx in enumerate(chunks):
    for j, chunky in enumerate(chunks):
        sm=difflib.SequenceMatcher(None,chunkx,chunky)
        m[i][j] = sm.ratio()

# %%
from sklearn.manifold import TSNE

tsne_model = TSNE(n_components=2, verbose=1, random_state=0)

# %%
tsne = tsne_model.fit_transform(m)
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 700 / 700
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] Error after 83 iterations with early exaggeration: 13.379313
# [t-SNE] Error after 144 iterations: 0.633875

# %%
from sklearn.cluster import MiniBatchKMeans

kmeans_model = MiniBatchKMeans(n_clusters=5, init='k-means++', n_init=1, 
                         init_size=1000, batch_size=1000, verbose=False, max_iter=1000)
kmeans = kmeans_model.fit(m)
kmeans_clusters = kmeans.predict(m)
kmeans_distances = kmeans.transform(m)

# %%
import bokeh.plotting as bp
from bokeh.models import HoverTool, BoxSelectTool
from bokeh.plotting import figure, show, output_notebook

colormap = np.array([
    "#1f77b4", "#aec7e8", "#ff7f0e", "#ffbb78", "#2ca02c", 
    "#98df8a", "#d62728", "#ff9896", "#9467bd", "#c5b0d5", 
    "#8c564b", "#c49c94", "#e377c2", "#f7b6d2", "#7f7f7f", 
    "#c7c7c7", "#bcbd22", "#dbdb8d", "#17becf", "#9edae5"
])

output_notebook()
plot_author1 = bp.figure(plot_width=900, plot_height=700, title="Author1",
    tools="pan,wheel_zoom,box_zoom,reset,hover,previewsave",
    x_axis_type=None, y_axis_type=None, min_border=1)

plot_author1.scatter(x=tsne[:,0], y=tsne[:,1],
                    color=colormap[kmeans_clusters],
                    source=bp.ColumnDataSource({
                        "chunks": [x["title_chunks"] for x in author1], 
                        "title": [x["title"] for x in author1],
                        "cluster": kmeans_clusters
                    }))

hover = plot_author1.select(dict(type=HoverTool))
hover.tooltips={"chunks": "@chunks (title: \"@title\")", "cluster": "@cluster"}
show(plot_author1)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8dfea9ca-f87a-41b6-9cc8-ba4f4aeca138">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="71ace2e7-00f6-40c1-9e39-19eee43c6ae9"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("71ace2e7-00f6-40c1-9e39-19eee43c6ae9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '71ace2e7-00f6-40c1-9e39-19eee43c6ae9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"cae82782-9b38-41d2-98fd-4236ccf59b76":{"roots":{"references":[{"attributes":{"data_source":{"id":"561033a3-f59d-4f9e-86a7-74e12f69982e","type":"ColumnDataSource"},"glyph":{"id":"7fb66b1e-cd3e-443a-8197-6b08e920dc3b","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"5ab07a5f-2c44-4d7c-ab3f-8ac552bd92de","type":"Circle"},"selection_glyph":null},"id":"f40a2198-287f-4e7f-9e88-2fd706e8aeaf","type":"GlyphRenderer"},{"attributes":{"fill_color":{"field":"fill_color"},"line_color":{"field":"line_color"},"x":{"field":"x"},"y":{"field":"y"}},"id":"710ffff0-14ec-4a7f-922a-7a9733a1aa39","type":"Circle"},{"attributes":{"callback":null},"id":"ead6ef65-6828-4146-9ba9-d7a4e1c70408","type":"DataRange1d"},{"attributes":{"plot":{"id":"6dff7948-d2da-4f7b-afb7-713129cd8667","subtype":"Figure","type":"Plot"}},"id":"4db8f930-f4d4-489a-aab0-d880ef702a44","type":"ResetTool"},{"attributes":{"min_border":1,"plot_height":700,"plot_width":900,"renderers":[{"id":"cbcd363f-9077-4976-a9bb-5a997179f7c9","type":"BoxAnnotation"},{"id":"f40a2198-287f-4e7f-9e88-2fd706e8aeaf","type":"GlyphRenderer"}],"title":"Web Summit 2015 tweets (tf-idf)","tool_events":{"id":"70a8801a-1d48-4aae-b326-891344b8052f","type":"ToolEvents"},"tools":[{"id":"b8701b2f-2fee-4b0f-91bf-26ef5dd27610","type":"PanTool"},{"id":"9c7eb1a6-5314-491f-835a-8c2dd101c2a2","type":"WheelZoomTool"},{"id":"ddbb6f27-5166-4e0c-b912-f2dac5217954","type":"BoxZoomTool"},{"id":"a38d6931-45ed-4c1f-b88f-480bc9c5e36c","type":"ResetTool"},{"id":"9c41269e-284f-4251-94b9-ec2dabb9c5a3","type":"HoverTool"},{"id":"06db248c-fc26-4739-b4d2-51b5230d9ea7","type":"PreviewSaveTool"}],"x_range":{"id":"ebfbb2f4-4ee8-412e-8452-11acf0758425","type":"DataRange1d"},"y_range":{"id":"7414f02d-ec20-40f1-a956-0c63cc9372c8","type":"DataRange1d"}},"id":"ef4a85cd-7098-4d39-8c4f-41313e15791a","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"e5737289-c35b-43e1-89ad-905dbb3af383","subtype":"Figure","type":"Plot"}},"id":"c9973459-3fd8-4090-905c-4b51488c5ba8","type":"WheelZoomTool"},{"attributes":{},"id":"70f0f5d4-5daf-4f9b-8006-b8da87fd2077","type":"ToolEvents"},{"attributes":{"callback":null},"id":"87c23a72-3b53-43ee-83f6-7d36c53a3e29","type":"DataRange1d"},{"attributes":{"plot":{"id":"a2718cee-322e-4f39-b3b0-51b4a46933c2","subtype":"Figure","type":"Plot"}},"id":"4d0923a6-0f97-4ec3-a28e-07cc75335f59","type":"PanTool"},{"attributes":{"min_border":1,"plot_height":700,"plot_width":900,"renderers":[{"id":"1ea8d4a7-4a86-462c-bac2-4132d4cebc55","type":"BoxAnnotation"},{"id":"4104af85-1e30-4c33-bfab-d3512873d2de","type":"GlyphRenderer"}],"title":"Author1","tool_events":{"id":"661beccf-7cc0-422e-9003-ce12a7bd92cf","type":"ToolEvents"},"tools":[{"id":"5e32bce2-f2bc-4503-a5a4-df8c548065f0","type":"PanTool"},{"id":"cbeeca07-a232-4f38-98fb-38f4e29f7f87","type":"WheelZoomTool"},{"id":"69643f19-eb5d-4d68-af56-6a98ee1a2c17","type":"BoxZoomTool"},{"id":"2c4db44a-7246-4e6c-a2b5-8511dbda1a31","type":"ResetTool"},{"id":"34d38e82-b49b-4588-bb87-8b5f29c11234","type":"HoverTool"},{"id":"8b5161d5-464f-4a81-a7de-9c23d8a2e937","type":"PreviewSaveTool"}],"x_range":{"id":"26a10644-56a3-4330-b5f3-969433e63720","type":"DataRange1d"},"y_range":{"id":"28133c7a-c5f3-4442-91c5-1a09009479a7","type":"DataRange1d"}},"id":"d6073d9c-400c-4055-be37-3445b424e60c","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"d6073d9c-400c-4055-be37-3445b424e60c","subtype":"Figure","type":"Plot"}},"id":"8b5161d5-464f-4a81-a7de-9c23d8a2e937","type":"PreviewSaveTool"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0bf99057-9cd8-4aa7-8041-a68fffa71828","type":"Circle"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":" ...
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-180-a533e7aec895> in <module>()
#      25 hover = plot_author1.select(dict(type=HoverTool))
#      26 hover.tooltips={"chunks": "@chunks (title: \"@title\")", "cluster": "@cluster"}
# ---> 27 show(plot_author1)
#
# /usr/local/lib/python2.7/site-packages/bokeh/io.pyc in show(obj, browser, new)
#     299
#     300     '''
# --> 301     return _show_with_state(obj, _state, browser, new)
#     302
#     303 def _show_with_state(obj, state, browser, new):
#
# /usr/local/lib/python2.7/site-packages/bokeh/io.pyc in _show_with_state(obj, state, browser, new)
#     307
#     308     if state.notebook:
# --> 309         comms_handle = _show_notebook_with_state(obj, state)
#     310
#     311     elif state.server_enabled:
#
# /usr/local/lib/python2.7/site-packages/bokeh/io.pyc in _show_notebook_with_state(obj, state)
#     329         comms_target = make_id()
#     330         publish_display_data({'text/html': notebook_div(obj, comms_target)})
# --> 331         handle = _CommsHandle(get_comms(comms_target), state.document, state.document.to_json())
#     332         state.last_comms_handle = handle
#     333         return handle
#
# /usr/local/lib/python2.7/site-packages/bokeh/util/notebook.pyc in get_comms(target_name)
#     109
#     110     '''
# --> 111     from ipykernel.comm import Comm
#     112     return Comm(target_name=target_name, data={})
#     113
#
# /usr/local/lib/python2.7/site-packages/ipykernel/__init__.py in <module>()
#       1 from ._version import version_info, __version__
# ----> 2 from .connect import *
#
# /usr/local/lib/python2.7/site-packages/ipykernel/connect.py in <module>()
#      11
#      12 from IPython.core.profiledir import ProfileDir
# ---> 13 from IPython.paths import get_ipython_dir
#      14 from ipython_genutils.path import filefind
#      15 from ipython_genutils.py3compat import str_to_bytes
#
# ImportError: No module named paths

# %%
author2 = pickle.load( open( "author2.p", "rb" ) )
for story in author2:
    story["title_length"] = len(story["title"])
    story["title_chunks"] = [chunk.type for chunk in parsetree(story["title"])[0].chunks]
    story["title_chunks_length"] = len(story["title_chunks"])

# %%
pd.DataFrame.from_dict(author2).describe()
# Out:
#        title_chunks_length  title_length
# count           700.000000    700.000000
# mean              5.452857     62.532857
# std               1.896252      9.996154
# min               1.000000     35.000000
# 25%               4.000000     57.000000
# 50%               5.000000     62.000000
# 75%               7.000000     68.000000
# max              13.000000     96.000000

# %%
chunks_a2 = [author["title_chunks"] for author in (author1+author2)]
m_a2 = np.zeros((1400,1400))
for i, chunkx in enumerate(chunks):
    for j, chunky in enumerate(chunks):
        sm=difflib.SequenceMatcher(None,chunkx,chunky)
        m_a2[i][j] = sm.ratio()

# %%
tsne_joint = tsne_model.fit_transform(m_a2)
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1400
# [t-SNE] Computed conditional probabilities for sample 1400 / 1400
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] Error after 83 iterations with early exaggeration: 12.344255
# [t-SNE] Error after 139 iterations: 0.789386

# %%
plot_joint = bp.figure(plot_width=900, plot_height=700, title="Author1 vs. Author2",
    tools="pan,wheel_zoom,box_zoom,reset,hover,previewsave",
    x_axis_type=None, y_axis_type=None, min_border=1)

plot_joint.scatter(x=tsne_joint[:,0], y=tsne_joint[:,1],
                    color=colormap[([0] * 700 + [1] * 700)],
                    source=bp.ColumnDataSource({
                        "chunks": [x["title_chunks"] for x in author1] + [x["title_chunks"] for x in author2], 
                        "title": [x["title"] for x in author1] + [x["title"] for x in author2]
                    }))

hover = plot_joint.select(dict(type=HoverTool))
hover.tooltips={"chunks": "@chunks (title: \"@title\")"}
show(plot_joint)
# Out:
#     <div class="plotdiv" id="bfa8b07b-7e1a-4c72-b28c-03ace9b8957f"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bfa8b07b-7e1a-4c72-b28c-03ace9b8957f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bfa8b07b-7e1a-4c72-b28c-03ace9b8957f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"edc0b9ac-4023-41c9-8c9e-002bf96067d0":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["chunks","title","y","x"],"data":{"chunks":[["NP","PP","NP","VP"],["NP","VP","NP","PP","NP","NP"],["NP","VP","NP","PP","NP","VP","ADJP","PP","NP","VP","NP"],["NP","NP","VP","NP","NP","VP","PP"],["NP","VP","ADVP","NP","NP","NP","NP","NP","NP","NP","NP","NP","NP","NP","NP","NP","NP"],["VP","NP"],["NP","VP","PP","NP"],["NP","VP","PP","NP"],["NP","VP","ADVP"],["VP","NP"],["NP","VP","ADJP","PP","NP","NP","NP"],["NP","VP","ADJP","PP","NP"],["NP","VP","ADJP","PP","NP"],["NP","VP","NP","PP","NP","VP","ADJP","PP","NP","VP","NP"],["NP","VP","PP","NP","PP","NP"],["NP","VP","PP","NP","VP","PP","NP"],["NP","NP","VP"],["NP","NP","VP"],["VP","NP","VP","NP","NP","VP","ADVP"],["NP","PP","NP"],["NP","VP","PP","VP","PP","NP"],["VP","NP"],["ADVP","NP","VP","ADVP","PP","ADJP"],["NP","NP","VP"],["VP","NP","NP","VP","PP","ADVP","NP","NP","NP","NP","NP","NP","NP","NP"],["NP","VP","ADJP","PP","NP","NP","VP"],["NP","VP","NP","NP","VP"],["NP","PP","NP"],["NP","PP","NP"],["NP","PP","NP","VP"],["NP","NP","VP","NP"],["VP","NP"],["NP","VP","NP","VP"],["VP","NP","NP","VP","PP","ADVP","NP","NP","NP","NP","NP","NP","NP","NP","NP","NP"],["NP","VP","NP","PP","NP"],["VP","NP","VP","PP","NP","NP","NP"],["NP","VP"],["VP","NP","NP","VP","PP","ADVP"],["NP","VP","PP","NP","VP"],["NP","VP","NP","PP","NP","NP"],["NP","VP","NP","PP","NP","NP"],["NP","VP","NP"],["NP","VP","NP"],["NP","VP","ADVP","NP","NP","NP","NP","NP","NP","NP","NP","NP"],["NP","NP","VP","NP","NP","VP","PP"],["VP","NP","NP","VP","PP","ADVP","NP","NP","NP","NP","NP","NP","NP"],["NP","PP","NP","NP","PP","NP","VP"],["NP","PP","NP","NP","PP","NP","VP"],["NP","VP"],["NP","NP","VP","NP","VP","NP","PP","NP"],["NP","PP","NP","VP","PP","NP","PP","NP"],["NP","NP","VP","NP","ADJP"],["NP","NP","VP","PP","VP","NP"],["NP","VP","PP","NP"],["VP","NP"],["VP","NP"],["NP","VP","ADJP","PP","VP"],["VP","NP"],["VP","NP"],["VP","NP"],["VP","NP","NP","VP","PP","ADVP","NP","NP","NP","NP","NP","NP","NP"],["NP","VP","PP","VP","NP","VP"],["NP","VP","NP","NP","VP","ADVP","PP"],["NP","VP","ADVP"],["NP","VP","ADJP","PP","VP","PP","NP"],["VP","NP"],["NP","PP","NP","VP","PP","NP","PP","NP"],["VP","NP","NP","VP","PP","ADVP"],["NP","VP","PP","NP","NP","VP"],["NP","VP","PP","NP"],["NP","VP","NP","VP"],["VP","NP"],["NP","VP"],["NP","VP","NP","ADJP","PP","NP"],["NP"],["VP","NP","NP","VP","PP","ADVP","NP","NP","NP","NP","NP","NP","NP","NP","NP"],["NP","VP","PP","NP","PP","NP","VP","NP"],["NP","VP","PP","NP","PP","NP","VP","NP"],["NP","VP","NP","PP","NP"],["NP","VP","NP","PP","NP"],["VP","NP","NP","VP","PP","ADVP","NP","NP","NP","NP","NP","NP","NP","NP","NP","NP","NP","NP","NP","ADJP","NP"],["NP","VP","NP"],["NP","VP","NP"],["NP","VP","NP"],["VP","NP"],["VP","NP","NP","VP","ADJP","NP","PP"],["NP","VP","NP","PP","VP","NP"],["NP","NP","VP","NP","VP","NP","PP","NP"],["NP","VP"],["NP","NP","VP","NP","ADJP"],["VP","NP","NP","VP","PP","ADVP","NP","NP","NP","ADJP","NP","NP","NP","NP"],["NP","VP","NP","NP","PP","NP","NP"],["NP","VP","NP","NP","PP","NP","NP"],["NP","ADVP","NP","VP","PP","NP"],["ADJP","PP","NP","PP","NP"],["NP","NP","PP","NP","VP","NP","PP","NP","NP"],["NP","VP","NP","VP"],["VP","NP"],["NP","VP","PP","NP","VP","PP","NP"],["NP","VP","PP","NP","VP","PP","NP"],["PP","NP","VP","PP","ADVP"],["PP","NP","VP","PP","ADVP"],["PP","NP","VP","PP","ADVP"],["NP","VP"],["NP","VP"],["NP","VP","NP","PP","NP","VP","ADVP"],["VP","NP","NP","VP","PP","ADVP","NP","NP","NP","NP"],["NP","VP","PP","PP","VP","NP","PP","NP"],["NP","VP"],["NP","VP"],["NP","VP"],["NP","ADVP","PP","VP"],["NP","ADVP","PP","VP"],["VP","NP"],["NP","ADVP","NP","VP","PP","NP"],["VP","NP","NP","VP","PP","ADVP"],["NP","NP","VP","NP","VP"],["NP","VP","NP","VP"],["VP","NP"],["NP","PP","NP","VP","NP","PP","VP","NP"],["NP","PP","NP","VP","NP","PP","VP","NP"],["NP","VP","PP","NP","PP","NP"],["VP","NP","NP","VP","PP","ADVP","NP","NP","NP","NP","NP","NP","NP" ...
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-211-e96f4b40d978> in <module>()
#      12 hover = plot_joint.select(dict(type=HoverTool))
#      13 hover.tooltips={"chunks": "@chunks (title: \"@title\")"}
# ---> 14 show(plot_joint)
#
# /usr/local/lib/python2.7/site-packages/bokeh/io.pyc in show(obj, browser, new)
#     299
#     300     '''
# --> 301     return _show_with_state(obj, _state, browser, new)
#     302
#     303 def _show_with_state(obj, state, browser, new):
#
# /usr/local/lib/python2.7/site-packages/bokeh/io.pyc in _show_with_state(obj, state, browser, new)
#     307
#     308     if state.notebook:
# --> 309         comms_handle = _show_notebook_with_state(obj, state)
#     310
#     311     elif state.server_enabled:
#
# /usr/local/lib/python2.7/site-packages/bokeh/io.pyc in _show_notebook_with_state(obj, state)
#     329         comms_target = make_id()
#     330         publish_display_data({'text/html': notebook_div(obj, comms_target)})
# --> 331         handle = _CommsHandle(get_comms(comms_target), state.document, state.document.to_json())
#     332         state.last_comms_handle = handle
#     333         return handle
#
# /usr/local/lib/python2.7/site-packages/bokeh/util/notebook.pyc in get_comms(target_name)
#     109
#     110     '''
# --> 111     from ipykernel.comm import Comm
#     112     return Comm(target_name=target_name, data={})
#     113
#
# /usr/local/lib/python2.7/site-packages/ipykernel/__init__.py in <module>()
#       1 from ._version import version_info, __version__
# ----> 2 from .connect import *
#
# /usr/local/lib/python2.7/site-packages/ipykernel/connect.py in <module>()
#      11
#      12 from IPython.core.profiledir import ProfileDir
# ---> 13 from IPython.paths import get_ipython_dir
#      14 from ipython_genutils.path import filefind
#      15 from ipython_genutils.py3compat import str_to_bytes
#
# ImportError: No module named paths
